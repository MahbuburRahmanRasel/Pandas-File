# %% [markdown]
# # 9. How do I apply multiple filter criteria to a pandas DataFrame?[Video](https://www.youtube.com/watch?v=YPItfQ87qjM&list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y&index=9)

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  blue solid !important;
#   color: black !important;
# }
# .CodeMirror{
#     font-size: 14px;
#     font-family:"verdana";
#     letter-spacing: .5px
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  blue solid !important;
#   color: black !important;
# }
# .CodeMirror{
#     font-size: 14px;
#     font-family:"verdana";
#     letter-spacing: .5px
# }
# </style>

# %%
import pandas as pd

# %%
movies= pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv")

# %%
movies.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %% [markdown]
# ### Single Criteria

# %%
movies[movies.duration>=150]
# Out:
#      star_rating                                  title content_rating  \
# 1            9.2                          The Godfather              R
# 2            9.1                 The Godfather: Part II              R
# 3            9.0                        The Dark Knight          PG-13
# 4            8.9                           Pulp Fiction              R
# 6            8.9         The Good, the Bad and the Ugly      NOT RATED
# ..           ...                                    ...            ...
# 909          7.5  Harry Potter and the Sorcerer's Stone             PG
# 941          7.4                       A Bridge Too Far             PG
# 955          7.4                       Zero Dark Thirty              R
# 964          7.4                                Lincoln          PG-13
# 968          7.4                    The English Patient              R
#
#          genre  duration                                        actors_list
# ...

# %% [markdown]
# __Understanding logical operators:__
#
#     *and: True only if both sides of the operator are True
#      or: True if either side of the operator is True

# %%
# demonstration of the 'and' operator
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
# demonstration of the 'or' operator
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %% [markdown]
# __Rules for specifying multiple filter criteria in pandas:__
#
#     *use & instead of and
#     use | instead of or
#     add parentheses around each condition to specify evaluation order

# %% [markdown]
# __Goal:__ Further filter the DataFrame of long movies (duration >= 200) to only show movies which also have a 'genre' of 'Drama'

# %%
# CORRECT: use the '&' operator to specify that both conditions are required
movies[(movies.duration >=200) & (movies.genre == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
# CORRECT: using the '|' operator would have shown movies that are either long or dramas (or both)
movies[(movies.duration >=200) | (movies.genre == 'Drama')].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 5           8.9                                   12 Angry Men      NOT RATED
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 9           8.9                                     Fight Club              R
# 13          8.8                                   Forrest Gump          PG-13
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 5       Drama        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 9       Drama       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13      Drama       142    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']

# %%
# use the '|' operator to specify that a row can match any of the three criteria
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')].head(10)
# Out:
#     star_rating                                           title  \
# 0           9.3                        The Shawshank Redemption
# 1           9.2                                   The Godfather
# 2           9.1                          The Godfather: Part II
# 3           9.0                                 The Dark Knight
# 4           8.9                                    Pulp Fiction
# 5           8.9                                    12 Angry Men
# 9           8.9                                      Fight Club
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                    Forrest Gump
#
#    content_rating   genre  duration  \
# 0               R   Crime       142
# 1               R   Crime       175
# 2               R   Crime       200
# 3           PG-13  Action       152
# 4               R   Crime       154
# 5       NOT RATED   Drama        96
# ...

# %% [markdown]
# ### isin Method

# %%
# or equivalently, use the 'isin' method
movies[movies.genre.isin(['Crime', 'Drama', 'Action'])].head(10)
# Out:
#     star_rating                                           title  \
# 0           9.3                        The Shawshank Redemption
# 1           9.2                                   The Godfather
# 2           9.1                          The Godfather: Part II
# 3           9.0                                 The Dark Knight
# 4           8.9                                    Pulp Fiction
# 5           8.9                                    12 Angry Men
# 9           8.9                                      Fight Club
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                    Forrest Gump
#
#    content_rating   genre  duration  \
# 0               R   Crime       142
# 1               R   Crime       175
# 2               R   Crime       200
# 3           PG-13  Action       152
# 4               R   Crime       154
# 5       NOT RATED   Drama        96
# ...
